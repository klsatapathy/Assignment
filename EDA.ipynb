# %% [markdown]
# # EDA - 1
# ## Title:  Bike Details Dataset
#
# ### Description:
# The dataset comprises 1061 records of used bike listings. These records include details about the bike's brand
# and model, selling price, kilometers driven, ownership history, and other attributes. It is particularly useful for
# resale value prediction, market analysis, and understanding buyer preferences.
#
#
# The dataset consists of 7 features, combining both numeric and categorical data, offering a comprehensive
# view of the second-hand bike market.
#
# * =name: Brand and model name of the bike (Categorical, e.g., "Royal Enfield Classic 350", "Honda Dio")Z
# * selling_price: Listed selling price in INR (Numeric, e.g., 175000, 45000)Z
# * year: Manufacturing year of the bike (Numeric, e.g., 2019, 2015)Z
# * seller_type: Seller category, either "Individual" or "Dealer" (Categorical)Z
# * owner: Ownership history, e.g., "1st owner", "2nd owner" (Categorical)Z
# * km_driven: Total kilometers driven (Numeric, in km, e.g., 12000, 23000)Z
# * ex_showroom_price: Original showroom price in INR (Numeric, e.g., 148114.0, 89643.0, etc,.).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("BIKE DETAILS.csv")

# %%
df.head(10)
# Out:
#                                    name  selling_price  year seller_type  \
# 0             Royal Enfield Classic 350         175000  2019  Individual
# 1                             Honda Dio          45000  2017  Individual
# 2   Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3     Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                 Yamaha SZ [2013-2014]          20000  2011  Individual
# 5                      Honda CB Twister          18000  2010  Individual
# 6                  Honda CB Hornet 160R          78500  2018  Individual
# 7  Royal Enfield Bullet 350 [2007-2011]         180000  2008  Individual
# 8                Hero Honda CBZ extreme          30000  2010  Individual
# 9                    Bajaj Discover 125          50000  2016  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# ...

# %%
df.tail(10)
# Out:
#                     name  selling_price  year seller_type      owner  \
# 1051  Bajaj Discover 125          20000  2014  Individual  2nd owner
# 1052           Hero Hunk          20000  2009  Individual  2nd owner
# 1053  Hero  Ignitor Disc          20000  2015  Individual  2nd owner
# 1054    Hero  CBZ Xtreme          20000  2010  Individual  1st owner
# 1055       Bajaj  ct 100          18000  2017  Individual  1st owner
# 1056           Activa 3g          17000  2010  Individual  1st owner
# 1057    Honda CB twister          16000  2012  Individual  1st owner
# 1058  Bajaj Discover 125          15000  2013  Individual  2nd owner
# 1059      Honda CB Shine          12000  2009  Individual  1st owner
# 1060    Bajaj Pulsar 150          10000  2008  Individual  1st owner
#
#       km_driven  ex_showroom_price
# 1051      25000            57000.0
# 1052      49000            75000.0
# 1053      24000            65000.0
# 1054      50000            78700.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.2+ KB

# %%
df.isnull().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
df['ex_showroom_price'].fillna(df['ex_showroom_price'].mean(), inplace=True)

# %%
df.describe()
# Out:
#        selling_price         year      km_driven  ex_showroom_price
# count    1061.000000  1061.000000    1061.000000       1.061000e+03
# mean    59638.151744  2013.867107   34359.833176       8.795871e+04
# std     56304.291973     4.301191   51623.152702       5.950722e+04
# min      5000.000000  1988.000000     350.000000       3.049000e+04
# 25%     28000.000000  2011.000000   13500.000000       6.458900e+04
# 50%     45000.000000  2015.000000   25000.000000       8.795871e+04
# 75%     70000.000000  2017.000000   43000.000000       8.795871e+04
# max    760000.000000  2020.000000  880000.000000       1.278000e+06

# %% [markdown]
# ### Ques- 1. What is the range of selling prices in the dataset ?

# %%
min_price = df['selling_price'].min()
max_price = df.selling_price.max()

# %%
Range_of_selling_price = max_price - min_price
Range_of_selling_price
# Out:
# np.int64(755000)

# %%
# The range of Selling price in data set is 755000 Ruppes

# %% [markdown]
# ### Ques - 2. What is the median selling price for bikes in the dataset?

# %%
median_price_for_bikes = df.selling_price.median()
median_price_for_bikes
# Out:
# np.float64(45000.0)

# %%
# The median selling price for bikes is 45000 rupees

# %% [markdown]
# ### Ques - 3. What is the most common seller type?

# %%
Seller_counts = df.seller_type.value_counts()
Seller_counts
# Out:
# seller_type
# Individual    1055
# Dealer           6
# Name: count, dtype: int64

# %%
most_common_seller_type = Seller_counts.idxmax()
most_common_seller_type
# Out:
# 'Individual'

# %%
# The most Common seller type is Individual.

# %% [markdown]
# ### Ques - 4. How many bikes have driven more than 50,000 kilometers?

# %%
Bike_km_driven_50000 = df[df['km_driven'] > 50000].shape[0]
Bike_km_driven_50000
# Out:
# 170

# %%
# 170 Bikes have driven more than 50,000 KM.

# %% [markdown]
# ### Ques - 5. What is the average km_driven value for each ownership type?

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
avg_km_value = df.groupby("owner")['km_driven'].mean().round(2)
avg_km_value
# Out:
# owner
# 1st owner     32816.58
# 2nd owner     39288.99
# 3rd owner     33292.18
# 4th owner    311500.00
# Name: km_driven, dtype: float64

# %%
# The avg km driven value of 1st owner is 32816.58 km
# The avg km driven value of 2nd owner is 39288.99 km
# The avg km driven value of 3rd owner is 33292.18 km
# The avg km driven value of 4th owner is 311500 km

# %% [markdown]
# ### Ques - 6. What proportion of bikes are from the year 2015 or older?

# %%
total_bikes = df.shape[0]
total_bikes
# Out:
# 1061

# %%
year_2015_or_older = df[df['year'] <= 2015].shape[0]
year_2015_or_older
# Out:
# 601

# %%
porportion = year_2015_or_older / total_bikes
porportion
# Out:
# 0.5664467483506126

# %%
# Proportion of bikes from the year 2015 or older is 0.5664467483506126

# %% [markdown]
# ### Ques - 7. What is the trend of missing values across the dataset ?

# %%
missing_value = df.isnull().sum()
missing_value
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
missing_value[missing_value > 0].plot(kind='bar', figsize=(10, 6))
plt.title('Missing Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### Ques - 8.  What is the highest ex_showroom_price recorded, and for which bike?

# %%
highest_price_index = df['ex_showroom_price'].idxmax()
highest_price_index
# Out:
# 134

# %%
highest_price_bike = df.loc[highest_price_index]
highest_price_bike
# Out:
# name                 Harley-Davidson Street Bob
# selling_price                            750000
# year                                       2013
# seller_type                          Individual
# owner                                 2nd owner
# km_driven                                 12000
# ex_showroom_price                     1278000.0
# Name: 134, dtype: object

# %%
# The highest ex showroom price recorded is 1278000.0
# For Harley-Davidson Street Bob

# %% [markdown]
# ### Ques - 9 .What is the total number of bikes listed by each seller type?

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
total_bikes_by_seller = df.groupby('seller_type')['name'].count()
total_bikes_by_seller
# Out:
# seller_type
# Dealer           6
# Individual    1055
# Name: name, dtype: int64

# %%
# The Individual Seller listed 1055 bikes
# Dealer are listed 6 bikes

# %% [markdown]
# ### Ques - 10. What is the relationship between selling_price and km_driven for first-owner bikes?

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
first_owner_bikes = df[df['owner'] == '1st owner']
first_owner_bikes
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 5                        Honda CB Twister          18000  2010  Individual
# ...                                   ...            ...   ...         ...
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
plt.figure(figsize=(12, 8))
plt.scatter(first_owner_bikes['km_driven'], first_owner_bikes['selling_price'])
plt.title('Selling Price VS Kilometers Driven for First-Owner Bikes')
plt.xlabel('Kilometers Driven')
plt.ylabel('Selling Price')
plt.legend()
plt.show()

# %%
correlation = first_owner_bikes['selling_price'].corr(first_owner_bikes['km_driven'])
correlation
# Out:
# np.float64(-0.24348174844965703)

# %%
# The Correlation coefficient between selling_price and km_driven for first-owner bikes is 0.24348174844965703

# %% [markdown]
# ### Ques - 11.  Identify and remove outliers in the km_driven column using the IQR method?

# %%
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(29500.0)

# %%
lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR
lower_fence
# Out:
# np.float64(-30750.0)

# %%
upper_fence
# Out:
# np.float64(87250.0)

# %%
df_remove_outliers = df[(df['km_driven'] >= lower_fence) & (df['km_driven'] <= upper_fence)]

# %%
df_remove_outliers.shape, df.shape
# Out:
# ((1022, 7), (1061, 7))

# %% [markdown]
# ### Ques - 12. Perform a bivariate analysis to visualize the relationship between year and selling_price

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='year', y = 'selling_price', data = df)
plt.title('Relationship between Year and Selling Price(Scatter Plot)')
plt.xlabel("Year")
plt.ylabel("Selling Price")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='year', y = 'selling_price', data = df)
plt.title('Relationship between Year and Selling Price(Box Plot)')
plt.xlabel("Year")
plt.ylabel("Selling Price")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Ques - 13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?

# %%
current_year = 2024

# %%
df['age_of_bikes'] = current_year - df['year']

# %%
average_price_by_age = df.groupby('age_of_bikes')['selling_price'].mean().reset_index()
average_price_by_age['depreciation'] = average_price_by_age['selling_price'].diff()

# %%
print(average_price_by_age)
# Out:
#     age_of_bikes  selling_price   depreciation
# 0              4  183333.333333            NaN
# 1              5  119689.511628  -63643.821705
# 2              6   87660.374046  -32029.137582
# 3              7   78894.736842   -8765.637204
# 4              8   58469.018692  -20425.718151
# 5              9   56500.000000   -1969.018692
# 6             10   48668.131868   -7831.868132
# 7             11   51136.986301    2468.854433
# 8             12   35748.400000  -15388.586301
# 9             13   35655.721311     -92.678689
# 10            14   31793.333333   -3862.387978
# 11            15   22267.857143   -9525.476190
# 12            16   34289.285714   12021.428571
# 13            17   24927.586207   -9361.699507
# 14            18   23380.000000   -1547.586207
# 15            19   16978.571429   -6401.428571
# 16            20   15100.000000   -1878.571429
# 17            21    8000.000000   -7100.000000
# 18            22   20666.666667   12666.666667
# ...

# %% [markdown]
# ### Ques - 14. Which bike names are priced significantly above the average price for their manufacturing year?

# %%
average_price_by_year = df.groupby('year')['selling_price'].mean().reset_index()

# %%
average_price_by_year.rename(columns={'selling_price': 'average_price'}, inplace=True)
average_price_by_year
# Out:
#     year  average_price
# 0   1988   20000.000000
# 1   1991    6000.000000
# 2   1993  130000.000000
# 3   1995  150000.000000
# 4   1997   17500.000000
# 5   1998   28333.333333
# 6   1999   15000.000000
# 7   2000   20833.333333
# 8   2001   40000.000000
# 9   2002   20666.666667
# 10  2003    8000.000000
# 11  2004   15100.000000
# 12  2005   16978.571429
# 13  2006   23380.000000
# 14  2007   24927.586207
# 15  2008   34289.285714
# 16  2009   22267.857143
# 17  2010   31793.333333
# 18  2011   35655.721311
# 19  2012   35748.400000
# 20  2013   51136.986301
# 21  2014   48668.131868
# 22  2015   56500.000000
# 23  2016   58469.018692
# 24  2017   78894.736842
# 25  2018   87660.374046
# 26  2019  119689.511628
# 27  2020  183333.333333

# %%
df = df.merge(average_price_by_year, on='year')

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price', 'average_price'],
#       dtype='object')

# %%
threshold = 0.10
df['is_significantly_above'] = df['selling_price'] > (df['average_price'] * (1 + threshold))

# %%
result = df[df['is_significantly_above']][['name', 'year', 'selling_price', 'average_price']]
result
# Out:
#                                       name  year  selling_price  average_price
# 0                Royal Enfield Classic 350  2019         175000  119689.511628
# 2      Royal Enfield Classic Gunmetal Grey  2018         150000   87660.374046
# 3        Yamaha Fazer FI V 2.0 [2016-2018]  2015          65000   56500.000000
# 7     Royal Enfield Bullet 350 [2007-2011]  2008         180000   34289.285714
# 13                           Yamaha YZF R3  2019         365000  119689.511628
# ...                                    ...   ...            ...            ...
# 996                          Honda CBR 150  2016          65000   58469.018692
# 997                           Hero Extreme  2015          65000   56500.000000
# 1005                    TVS Apache RTR 160  2014          60000   48668.131868
# 1008                    Bajaj Pulsar 220 F  2012          52000   35748.400000
# 1023                Bajaj Avenger 220 dtsi  2012          45000   35748.400000
#
# [270 rows x 4 columns]

# %%
# Royal Enfield Classic 350 priced significantly above the average price for their manufacturing year

# %% [markdown]
# ### Ques - 15. Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(12, 8)) 
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# # EDA - 2
#
# ## Title: Car Sale Dataset
#
# ### Description:
#
# The dataset contains details about used cars listed for sale, such as brand, model, selling price, kilometers
# driven, fuel type, and transmission type. This information is valuable for predictive modeling, market analysis,
# and understanding customer preferences.
#
# ### Features:
# * Car_id: A unique identifier for each car in the dataset, helping to track individual car entries
# * Date: The date when the car sale transaction took place, formatted as YYYY-MM-DD.
# * Customer Name: The name of the customer who purchased the car, represented as a string.
# * Gender: The gender of the customer, categorized as "Male" or "Female.
# * Annual Income: The customer's annual income in US dollars, represented as a numeric value.
# * Dealer_Name: The name of the dealership selling the car, represented as a string.
# * Company: The manufacturer or brand name of the car, such as "Toyota," "Ford," etc.
# * Model: The specific model name of the car, such as "Corolla," "Civic," etc.
# * Engine: The engine type of the car, such as "V6," "I4," etc.
# * Transmission: The type of transmission in the car, either "Manual" or "Automatic.
# * Color: The color of the car, represented as a string (e.g., "Red," "Blue").
# * Price ($): The selling price of the car in US dollars.
# * Dealer_No: A unique identifier for each car dealer in the dataset.
# * Body Style: The body style of the car, such as "Sedan," "SUV," etc.
# * Phone: The phone number of the customer who purchased the car.
# * Dealer_Region: The geographical region of the car dealer, such as "North," "South," etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Car Sale.csv")

# %%
df.head()
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# ...

# %%
df.tail()
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price ($)  \
# 23901          Overhead Camshaft       Manual         Red      12000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
df.describe()
# Out:
#        Annual Income     Price ($)         Phone
# count   2.390600e+04  23906.000000  2.390600e+04
# mean    8.308403e+05  28090.247846  7.497741e+06
# std     7.200064e+05  14788.687608  8.674920e+05
# min     1.008000e+04   1200.000000  6.000101e+06
# 25%     3.860000e+05  18001.000000  6.746495e+06
# 50%     7.350000e+05  23000.000000  7.496198e+06
# 75%     1.175750e+06  34000.000000  8.248146e+06
# max     1.120000e+07  85800.000000  8.999579e+06

# %%
df.isnull().sum()
# Out:
# Car_id           0
# Date             0
# Customer Name    1
# Gender           0
# Annual Income    0
# Dealer_Name      0
# Company          0
# Model            0
# Engine           0
# Transmission     0
# Color            0
# Price ($)        0
# Dealer_No        0
# Body Style       0
# Phone            0
# Dealer_Region    0
# dtype: int64

# %% [markdown]
# ### Ques - 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
average_price_by_dealer = df.groupby('Dealer_Name')['Price ($)'].mean().reset_index()

# %%
average_price_by_dealer.sort_values(by='Price ($)', ascending=False, inplace=True)
average_price_by_dealer
# Out:
#                                         Dealer_Name     Price ($)
# 27                                        U-Haul CO  28769.919006
# 5                                     Classic Chevy  28602.014446
# 19                             Rabun Used Car Sales  28527.536177
# 11                                  Iceberg Rentals  28522.958533
# 8                             Enterprise Rent A Car  28312.580800
# 23                Scrivener Performance Engineering  28297.371589
# 9                        Gartner Buick Hyundai Saab  28247.621019
# 22                                 Saab-Belle Dodge  28190.139888
# 2                                       Capitol KIA  28189.703822
# 20                                    Race Car Help  28163.372706
# 4                            Chrysler of Tri-Cities  28123.091054
# 24                             Star Enterprises Inc  28113.055244
# 25                                    Suburban Ford  28112.206758
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Dealer_Name', y='Price ($)', data=average_price_by_dealer)
plt.title('Average Selling Price of Cars by Dealer')
plt.xlabel('Dealer Name')
plt.ylabel('Average Selling Price ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Avrage selling price almost same of Every Dealer

# %% [markdown]
# ### Ques -2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
price_variation_by_brand = df.groupby('Company')['Price ($)'].std().reset_index()

# %%
price_variation_by_brand.columns = ['Company', 'Price Variation']

# %%
price_variation_by_brand.sort_values(by='Price Variation', ascending=False, inplace=True)

# %%
price_variation_by_brand.reset_index(inplace=True)

# %%
price_variation_by_brand
# Out:
#     index     Company  Price Variation
# 0      15     Lincoln     19658.050211
# 1      24        Saab     19653.740089
# 2       4    Cadillac     19517.120220
# 3      21    Plymouth     19065.997338
# 4      14       Lexus     17852.923492
# 5       3       Buick     17142.232626
# 6      17     Mercury     16445.172195
# 7      19      Nissan     16214.264017
# 8      25      Saturn     15990.223671
# 9       8        Ford     15849.090227
# 10     16  Mercedes-B     15722.807459
# 11     20  Oldsmobile     15711.345857
# 12     27      Toyota     15367.131714
# 13      2         BMW     15065.578723
# 14     22     Pontiac     14348.963592
# 15     11    Infiniti     13696.332844
# 16      5   Chevrolet     13311.063223
# 17     29       Volvo     12933.790185
# 18     26      Subaru     12920.771620
# 19      1        Audi     12904.243867
# 20     28  Volkswagen     12527.124011
# 21     18  Mitsubishi     11671.343035
# 22      6    Chrysler     11583.286811
# ...

# %%
# Lincoln has the highest variation in prices

# %% [markdown]
# ### Ques - 3. What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Transmission', y='Price ($)', data=df)
plt.title('Distribution of Car Prices by Transmission Type')
plt.xlabel('Transmission Type')
plt.ylabel('Price ($)')
plt.legend()
plt.show()

# %%
Q3 = df.groupby('Transmission')['Price ($)'].quantile(0.75)
Q1 = df.groupby('Transmission')['Price ($)'].quantile(0.25)

# %%
IQR_by_transmission =  Q3 - Q1
IQR_by_transmission
# Out:
# Transmission
# Auto      16500.0
# Manual    17000.0
# Name: Price ($), dtype: float64

# %% [markdown]
# ### Ques - 4. What is the distribution of car prices across different regions?

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Dealer_Region', y='Price ($)', data=df, color='blue')
plt.title('Distribution of Car Prices Across Different Regions')
plt.xlabel('Region')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Dealer_Region', y='Price ($)',color='green', data=df)
plt.title('Distribution of Car Prices Across Different Regions')
plt.xlabel('Region')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)

plt.legend()
plt.show()

# %% [markdown]
# ### Ques -5. What is the distribution of cars based on body styles?

# %%
body_style_counts = df['Body Style'].value_counts()
body_style_counts
# Out:
# Body Style
# SUV          6374
# Hatchback    6128
# Sedan        4488
# Passenger    3945
# Hardtop      2971
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.barplot(body_style_counts, palette='rainbow')
plt.title('Distribution of Cars Based on Body Styles')
plt.xlabel('Body Style')
plt.ylabel('Number of Cars')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Most of cars Are SUV acording to Body Style

# %% [markdown]
# ### Ques - 6. How does the average selling price of cars vary by customer gender and annual income?

# %%
average_price_by_gender = df.groupby('Gender')['Price ($)'].mean().reset_index()
average_price_by_gender
# Out:
#    Gender     Price ($)
# 0  Female  28277.265270
# 1    Male  28039.429407

# %%
average_price_by_gender.columns = ['Gender', 'Average Price ($)']
average_price_by_gender
# Out:
#    Gender  Average Price ($)
# 0  Female       28277.265270
# 1    Male       28039.429407

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='Gender', y='Average Price ($)', data=average_price_by_gender, color='r')
plt.title('Average Selling Price of Cars by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Price ($)')
plt.legend()
plt.show()

# %%
# Average Price almost same in case of both gender

# %%
bins = [0, 30000, 60000, 90000, 120000, 150000, float('inf')]
labels = ['<30k', '30k-60k', '60k-90k', '90k-120k', '120k-150k', '150k+']
df['Income Bracket'] = pd.cut(df['Annual Income'], bins=bins, labels=labels)
df.head(2)
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
#
#                            Dealer_Name Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc    Ford  Expedition
# 1                     C & M Motors Inc   Dodge     Durango
#
#                       Engine Transmission  Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto  Black      26000  06457-3834
# 1  DoubleÂ Overhead Camshaft         Auto  Black      19000  60504-7114
#
#   Body Style    Phone Dealer_Region Income Bracket
# 0        SUV  8264678    Middletown           <30k
# 1        SUV  6848189        Aurora          150k+

# %%
average_price_by_income = df.groupby('Income Bracket')['Price ($)'].mean().reset_index()

# %%
average_price_by_income.columns = ['Income Bracket', 'Average Price ($)']
average_price_by_income
# Out:
#   Income Bracket  Average Price ($)
# 0           <30k       27884.297820
# 1        30k-60k                NaN
# 2        60k-90k       43000.000000
# 3       90k-120k       46001.000000
# 4      120k-150k       17500.000000
# 5          150k+       28149.089557

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Income Bracket', y='Average Price ($)', data=average_price_by_income, palette='tab10')
plt.title('Average Selling Price of Cars by Annual Income')
plt.xlabel('Annual Income Bracket')
plt.ylabel('Average Price ($)')
plt.show()

# %% [markdown]
# ### Ques-7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Dealer_Region', y='Price ($)', data=df, palette='bright')
plt.title('Distribution of Car Prices by Region')
plt.xlabel('Region')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Count the number of cars sold by region
cars_sold_by_region = df['Dealer_Region'].value_counts().reset_index()
cars_sold_by_region.columns = ['Dealer_Region', 'Number of Cars Sold']
cars_sold_by_region
# Out:
#   Dealer_Region  Number of Cars Sold
# 0        Austin                 4135
# 1    Janesville                 3821
# 2    Scottsdale                 3433
# 3         Pasco                 3131
# 4        Aurora                 3130
# 5    Greenville                 3128
# 6    Middletown                 3128

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Dealer_Region', y='Number of Cars Sold', data=cars_sold_by_region, palette='viridis')
plt.title('Number of Cars Sold by Region')
plt.xlabel('Region')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
# The Austin Region Dealer Sale most number of car

# %% [markdown]
# ### Ques - 8. How does the average car price differ between cars with different engine sizes?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
# Calculate the average selling price by engine size
average_price_by_engine_size = df.groupby('Engine')['Price ($)'].mean().reset_index()
average_price_by_engine_size.columns = ['Engine', 'Average Price ($)']
average_price_by_engine_size
# Out:
#                       Engine  Average Price ($)
# 0  DoubleÂ Overhead Camshaft       28248.525972
# 1          Overhead Camshaft       27914.710631

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Engine', y='Average Price ($)', data=average_price_by_engine_size, marker='o')
plt.title('Average Car Price by Engine Size')
plt.xlabel('Engine Size (L)')
plt.ylabel('Average Price ($)')
plt.show()

# %% [markdown]
# ### Ques -9. How do car prices vary based on the customer’s annual income bracket?

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Income Bracket', y='Average Price ($)', data=average_price_by_income, palette='coolwarm')
plt.title('Average Car Price by Customer Annual Income Bracket')
plt.xlabel('Annual Income Bracket')
plt.ylabel('Average Price ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Ques - 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
top_models = df['Model'].value_counts().head(5).reset_index()
top_models.columns = ['Model', 'Number of Sales']
top_models
# Out:
#         Model  Number of Sales
# 0    Diamante              418
# 1       Prizm              411
# 2  Silhouette              411
# 3      Passat              391
# 4  Ram Pickup              383

# %%
top_model_list = top_models['Model'].tolist()
top_models_data = df[df['Model'].isin(top_model_list)]
#top_models_data

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Model', y='Price ($)', data=top_models_data, palette='Paired')
plt.title('Price Distribution of Top 5 Car Models by Sales')
plt.xlabel('Car Model')
plt.ylabel('Price ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Ques-11. How does car price vary with engine size across different car colors, and which colors have the highest price variation?

# %%
price_variation = df.groupby(['Color', 'Engine'])['Price ($)'].std().reset_index()
price_variation.columns = ['Color', 'Engine Size', 'Price Variation ($)']
price_variation
# Out:
#         Color                Engine Size  Price Variation ($)
# 0       Black  DoubleÂ Overhead Camshaft         12418.674126
# 1       Black          Overhead Camshaft         17457.405345
# 2  Pale White  DoubleÂ Overhead Camshaft         14402.413401
# 3  Pale White          Overhead Camshaft         13000.103061
# 4         Red  DoubleÂ Overhead Camshaft         13499.354247
# 5         Red          Overhead Camshaft         17346.642554

# %%
max_variation_by_color = price_variation.groupby('Color')['Price Variation ($)'].max().reset_index()
max_variation_by_color = max_variation_by_color.sort_values(by='Price Variation ($)', ascending=False)
max_variation_by_color
# Out:
#         Color  Price Variation ($)
# 0       Black         17457.405345
# 2         Red         17346.642554
# 1  Pale White         14402.413401

# %%
heatmap_data = price_variation.pivot(index='Color', columns='Engine Size', values='Price Variation ($)')
heatmap_data
# Out:
# Engine Size  DoubleÂ Overhead Camshaft  Overhead Camshaft
# Color
# Black                     12418.674126       17457.405345
# Pale White                14402.413401       13000.103061
# Red                       13499.354247       17346.642554

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap='coolwarm', cbar_kws={'label': 'Price Variation ($)'})
plt.title('Price Variation by Engine Size and Car Color')
plt.xlabel('Engine Size (L)')
plt.ylabel('Car Color')
plt.show()

# %% [markdown]
# ### Ques- 12.  Is there any seasonal trend in car sales based on the date of sale?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Car_id              object
# Date                object
# Customer Name       object
# Gender              object
# Annual Income        int64
# Dealer_Name         object
# Company             object
# Model               object
# Engine              object
# Transmission        object
# Color               object
# Price ($)            int64
# Dealer_No           object
# Body Style          object
# Phone                int64
# Dealer_Region       object
# Income Bracket    category
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# %%
df.dtypes
# Out:
# Car_id                    object
# Date              datetime64[ns]
# Customer Name             object
# Gender                    object
# Annual Income              int64
# Dealer_Name               object
# Company                   object
# Model                     object
# Engine                    object
# Transmission              object
# Color                     object
# Price ($)                  int64
# Dealer_No                 object
# Body Style                object
# Phone                      int64
# Dealer_Region             object
# Income Bracket          category
# Year                       int32
# Month                      int32
# dtype: object

# %%
monthly_sales = df.groupby(['Year', 'Month']).size().reset_index(name='Sales')
monthly_sales
# Out:
#     Year  Month  Sales
# 0   2022      1    315
# 1   2022      2    320
# 2   2022      3    705
# 3   2022      4    800
# 4   2022      5    750
# 5   2022      6    690
# 6   2022      7    700
# 7   2022      8    810
# 8   2022      9   1475
# 9   2022     10    835
# 10  2022     11   1620
# 11  2022     12   1625
# 12  2023      1    475
# 13  2023      2    415
# 14  2023      3    830
# 15  2023      4    855
# 16  2023      5   1145
# 17  2023      6   1025
# 18  2023      7   1025
# 19  2023      8    895
# 20  2023      9   1830
# 21  2023     10    995
# 22  2023     11   1850
# 23  2023     12   1921

# %%
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales['Sales'])
plt.title('Monthly Car Sales Over Time')
plt.xlabel('Month')
plt.ylabel('Number of Cars Sold')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

df.set_index('Date', inplace=True)

# Decompose the time series
decomposition = seasonal_decompose(df['Price ($)'], model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# ### Ques- 13. How does the car price distribution change when considering different combinations of body style and transmission type?

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Body Style', y='Price ($)', hue='Transmission', data=df)
plt.title('Car Price Distribution by Body Style and Transmission Type')
plt.xticks(rotation=45)
plt.legend(title='Transmission Type')
plt.show()

# %% [markdown]
# ### Ques- 14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?

# %%
df.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region',
#        'Income Bracket', 'Year', 'Month'],
#       dtype='object')

# %%
corr_matrix = df[['Price ($)', 'Engine', 'Annual Income']].corr(numeric_only=True)
corr_matrix
# Out:
#                Price ($)  Annual Income
# Price ($)       1.000000       0.012065
# Annual Income   0.012065       1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.subplot(1, 2, 1)
sns.scatterplot(x='Engine', y='Price ($)', data=df)
plt.title('Car Price vs Engine Size')
plt.show()

# %%
# Scatter plot for Price vs Annual Income
plt.subplot(1, 2, 2)
sns.scatterplot(x='Annual Income', y='Price ($)', data=df)
plt.title('Car Price vs Annual Income')
plt.show()

# %%
sns.pairplot(df[['Price ($)', 'Engine', 'Annual Income']])
plt.show()

# %% [markdown]
# ### Ques- 15. How does the average car price vary across different car models and engine types?

# %%
average_price = df.groupby(['Model', 'Engine'])['Price ($)'].mean().reset_index()
average_price = average_price.sort_values(by='Price ($)', ascending=False)
average_price
# Out:
#         Model                     Engine     Price ($)
# 212        SC          Overhead Camshaft  61074.818182
# 198    Ranger  DoubleÂ Overhead Camshaft  61064.055556
# 222     Sable          Overhead Camshaft  61039.770833
# 56     Catera  DoubleÂ Overhead Camshaft  56836.933333
# 143     LX470          Overhead Camshaft  54037.490196
# ..        ...                        ...           ...
# 15         A4          Overhead Camshaft  12046.220000
# 241    Taurus  DoubleÂ Overhead Camshaft  11665.538462
# 98     Escort          Overhead Camshaft  11403.866667
# 129  Intrepid          Overhead Camshaft  11069.882353
# 155    Mirage  DoubleÂ Overhead Camshaft   9063.368421
#
# [261 rows x 3 columns]

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Price ($)', y='Model', hue='Engine', data=average_price, palette='viridis')
plt.title('Average Car Price by Model and Engine Type')
plt.xlabel('Average Price ($)')
plt.ylabel('Car Model')
plt.legend(title='Engine Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# # EDA - 3
#
# ## Title : Amazon Sales Data
#
# ### Description:
# This dataset contains information on 1K+ Amazon products, including their ratings, reviews, and other details.
#
# ### Features:
# * product_id: Unique identifier for each product
#
# * product_name: Name of the product
#
# * category: Category of the product
#
# * discounted_price: Discounted price of the product
#
# * actual_price: Actual price of the product
#
# * discount_percentage: Percentage of discount for the product
#
# * rating: Rating of the product (1-5)
#
# * rating_count: Number of people who voted for the Amazon rating
#
# * about_product: Description about the product
#
# * user_id: ID of the user who wrote the review
#
# * user_name: Name of the user who wrote the review
#
# * review_id: ID of the user review
#
# * review_title: Short review
#
# * review_content: Long review
#
# * img_link: Image link of the product
#
# * product_link: Official website link of the product

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("amazon.csv")

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.tail()
# Out:
#       product_id                                       product_name  \
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# ### Ques-1. What is the average rating for each product category?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.rating.dtype
# Out:
# dtype('O')

# %%
df.rating.unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# %%
df = df.dropna(subset=['rating'])

# %%
print(df['rating'].isnull().sum())
# Out:
# 0

# %%
df.rating.unique()
# Out:
# array([4.2, 4. , 3.9, 4.1, 4.3, 4.4, 4.5, 3.7, 3.3, 3.6, 3.4, 3.8, 3.5,
#        4.6, 3.2, 5. , 4.7, 3. , 2.8, 3.1, 4.8, 2.3, 2. , 2.6, 2.9])

# %%
df['rating'] = df['rating'].astype(float)

# %%
df.rating.dtype
# Out:
# dtype('float64')

# %%
average_rating_by_category = df.groupby('category')['rating'].mean().reset_index()

average_rating_by_category.columns = ['category', 'average_rating']
average_rating_by_category
# Out:
#                                               category  average_rating
# 0    Car&Motorbike|CarAccessories|InteriorAccessori...        3.800000
# 1    Computers&Accessories|Accessories&Peripherals|...        4.150000
# 2    Computers&Accessories|Accessories&Peripherals|...        3.500000
# 3    Computers&Accessories|Accessories&Peripherals|...        3.600000
# 4    Computers&Accessories|Accessories&Peripherals|...        4.050000
# ..                                                 ...             ...
# 206  OfficeProducts|OfficePaperProducts|Paper|Stati...        4.250000
# 207  OfficeProducts|OfficePaperProducts|Paper|Stati...        4.150000
# 208  OfficeProducts|OfficePaperProducts|Paper|Stati...        4.300000
# 209  OfficeProducts|OfficePaperProducts|Paper|Stati...        4.133333
# 210  Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...        4.300000
#
# [211 rows x 2 columns]

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['rating'], bins=5, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Ques-2. What are the top rating_count products by category?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df['rating_count'].dtype
# Out:
# dtype('O')

# %%
df.rating_count.unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df['rating_count'] = pd.to_numeric(df['rating_count'], errors='coerce')

# %%
df = df.dropna(subset=['rating_count'])

# %%
top_products_by_category = df.loc[df.groupby('category')['rating_count'].idxmax()]

# %%
top_products_by_category = top_products_by_category[['category', 'product_name', 'rating_count']]
top_products_by_category
# Out:
#                                                category  \
# 900   Computers&Accessories|Accessories&Peripherals|...
# 32    Computers&Accessories|Accessories&Peripherals|...
# 743   Computers&Accessories|Accessories&Peripherals|...
# 653   Computers&Accessories|Accessories&Peripherals|...
# 940   Computers&Accessories|Accessories&Peripherals|...
# ...                                                 ...
# 1257  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...
# 1317  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# 1424  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# 808   OfficeProducts|OfficePaperProducts|Paper|Copy&...
# 950   OfficeProducts|OfficePaperProducts|Paper|Stati...
#
#                                            product_name  rating_count
# 900   Lapster USB 3.0 sata Cable for 2.5 inch SSD an...         817.0
# 32    Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...         974.0
# 743   Amazon Basics Magic Slate 8.5-inch LCD Writing...         401.0
# ...

# %% [markdown]
# ### Ques-3.  What is the distribution of discounted prices vs. actual prices?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.discounted_price.unique
# Out:
# <bound method Series.unique of 20        ₹970
# 28        ₹970
# 32        ₹389
# 33        ₹599
# 37        ₹199
#          ...
# 1453    ₹2,320
# 1456      ₹498
# 1458      ₹949
# 1459      ₹199
# 1462    ₹2,219
# Name: discounted_price, Length: 325, dtype: object>

# %%
df['discounted_price'] = df.discounted_price.str.replace('₹', '')

# %%
df.discounted_price.unique()
# Out:
# array(['970', '389', '599', '199', '399', '348', '263', '7,999', '349',
#        '10,901', '209', '1,434', '7,299', '299', '1,299', '228', '1,499',
#        '8,499', '179', '655', '499', '368', '29,990', '339', '637', '149',
#        '799', '205', '8,990', '320', '139', '225', '547', '11,990', '204',
#        '6,490', '235', '6,999', '848.99', '213', '598', '32,990',
#        '128.31', '449', '129', '790', '4,699', '1,990', '2,299', '119',
#        '417.44', '215', '249', '1,289', '1,850', '13,990', '185', '218',
#        '893', '10,990', '699', '2,699', '246', '247', '1,369', '197',
#        '9,499', '3,999', '2,999', '10,499', '4,499', '1,999', '4,999',
#        '2,499', '281', '7,998', '899', '99', '150', '265', '1,799', '219',
#        '289', '159', '89', '69', '469', '269', '1,599', '175', '116',
#        '1,409', '379', '300', '398', '1,519', '37,247', '3,599', '678',
#        '809', '1,099', '749', '1,049', '353', '1,498', '244', '1,959',
# ...

# %%
df['discounted_price'] = pd.to_numeric(df['discounted_price'], errors='coerce')

# %%
df.discounted_price.dtype
# Out:
# dtype('float64')

# %%
df.actual_price.unique()
# Out:
# array(['₹1,799', '₹1,999', '₹1,099', '₹599', '₹999', '₹349', '₹1,499',
#        '₹699', '₹14,990', '₹899', '₹499', '₹30,990', '₹3,999', '₹19,125',
#        '₹15,999', '₹299', '₹65,000', '₹799', '₹399', '₹849', '₹18,990',
#        '₹1,199', '₹549', '₹2,999', '₹31,990', '₹9,990', '₹16,990',
#        '₹1,490', '₹4,999', '₹56,790', '₹1,000', '₹4,699', '₹3,100',
#        '₹670', '₹2,499', '₹4,500', '₹28,900', '₹449', '₹1,052', '₹19,990',
#        '₹1,899', '₹3,500', '₹600', '₹11,999', '₹9,999', '₹7,990',
#        '₹13,499', '₹7,999', '₹8,499', '₹6,999', '₹5,999', '₹3,990',
#        '₹3,499', '₹1,290', '₹180', '₹99', '₹3,490', '₹1,299', '₹200',
#        '₹775', '₹2,199', '₹300', '₹1,949', '₹59,890', '₹7,950', '₹1,545',
#        '₹2,400', '₹2,000', '₹1,989', '₹1,699', '₹1,639', '₹2,300', '₹749',
#        '₹1,599', '₹2,900', '₹4,590', '₹1,990', '₹79', '₹1,950', '₹2,799',
#        '₹19,825', '₹239', '₹2,890', '₹4,560', '₹2,600', '₹3,300',
# ...

# %%
df['actual_price'] = df['actual_price'].str.replace('₹','').str.replace(',','')

# %%
df.actual_price.unique
# Out:
# <bound method Series.unique of 20      1799
# 28      1999
# 32      1099
# 33       599
# 37       999
#         ...
# 1453    3290
# 1456    1200
# 1458    2299
# 1459     999
# 1462    3080
# Name: actual_price, Length: 325, dtype: object>

# %%
df['discounted_price'] = pd.to_numeric(df['discounted_price'], errors='coerce')

# %%
df['discounted_price'].dtype
# Out:
# dtype('float64')

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['discounted_price'], bins=10, kde=True, color='blue')
plt.title('Distribution of Discounted Prices')
plt.xlabel('Discounted Price')
plt.ylabel('Frequency')



plt.subplot(1, 2, 2)
sns.histplot(df['actual_price'], bins=10, kde=True, color='orange')
plt.title('Distribution of Actual Prices')
plt.xlabel('Actual Price')
plt.ylabel('Frequency')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ques-4. How does the average discount percentage vary across categories?

# %%
print(df[['category', 'discount_percentage']].isnull().sum())
# Out:
# category               0
# discount_percentage    0
# dtype: int64

# %%
df.discount_percentage.unique()
# Out:
# array(['46%', '51%', '65%', '0%', '80%', '60%', '43%', '77%', '62%',
#        '47%', '61%', '42%', '58%', '64%', '70%', '35%', '75%', '63%',
#        '40%', '44%', '54%', '69%', '50%', '56%', '29%', '83%', '59%',
#        '53%', '55%', '82%', '66%', '67%', '57%', '88%', '87%', '36%',
#        '38%', '48%', '52%', '71%', '78%', '15%', '45%', '23%', '21%',
#        '22%', '76%', '86%', '33%', '74%', '90%', '73%', '17%', '12%',
#        '10%', '14%', '18%', '20%', '49%', '79%', '37%', '39%', '4%',
#        '27%', '11%', '31%', '72%', '28%'], dtype=object)

# %%
df.discount_percentage = df.discount_percentage.str.replace('%', '')

# %%
df.discount_percentage = df.discount_percentage.astype(int)

# %%
df.discount_percentage.dtype
# Out:
# dtype('int64')

# %%
average_discount = df.groupby('category')['discount_percentage'].mean().reset_index()
average_discount = average_discount.sort_values(by='discount_percentage', ascending=False)
average_discount
# Out:
#                                              category  discount_percentage
# 18  Electronics|Headphones,Earbuds&Accessories|Ear...                 90.0
# 33  Electronics|Mobiles&Accessories|MobileAccessor...                 90.0
# 3   Computers&Accessories|Accessories&Peripherals|...                 87.0
# 8   Computers&Accessories|Accessories&Peripherals|...                 80.0
# 12  Computers&Accessories|Components|InternalHardD...                 80.0
# ..                                                ...                  ...
# 11  Computers&Accessories|Accessories&Peripherals|...                 10.0
# 20  Electronics|HomeAudio|MediaStreamingDevices|St...                  0.0
# 57  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...                  0.0
# 81  OfficeProducts|OfficePaperProducts|Paper|Copy&...                  0.0
# 82  OfficeProducts|OfficePaperProducts|Paper|Stati...                  0.0
#
# [83 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='discount_percentage', y='category', data=average_discount, palette='viridis')
plt.title('Average Discount Percentage by Category')
plt.xlabel('Average Discount Percentage')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ### Ques-5. What are the most popular product names?

# %%
most_popular_products = df[['product_name', 'rating_count']].sort_values(by='rating_count', ascending=False)

most_popular_products = most_popular_products.head(10)

most_popular_products
# Out:
#                                            product_name  rating_count
# 750        Eveready Red 1012 AAA Batteries - Pack of 10         989.0
# 1059  Pigeon 1.5 litre Hot Kettle and Stainless Stee...         976.0
# 32    Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...         974.0
# 823   Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...         974.0
# 151   Zoul USB Type C Fast Charging 3A Nylon Braided...         974.0
# 1272  Bajaj New Shakti Neo Plus 15 Litre 4 Star Rate...         959.0
# 1259  Hindware Atlantic Xceed 5L 3kW Instant Water H...         942.0
# 214   Crypo™ Universal Remote Compatible with Tata S...         928.0
# 1262  iBELL Castor CTEK15L Premium 1.5 Litre Stainle...         925.0
# 147   Ambrane Fast 100W Output Cable with Type-C to ...         919.0

# %%
plt.figure(figsize=(12, 10))
sns.barplot(x='rating_count', y='product_name', data=most_popular_products, palette='rainbow')
plt.title('Top 10 Most Popular Products by Rating Count')
plt.xlabel('Number of Ratings')
plt.ylabel('Product Name')
plt.show()

# %%
# The Most Popular Product Name is Eveready Red 1012 AAA Batteries - Pack of 10

# %% [markdown]
# ### Ques-6.What are the most popular product keywords?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.product_name.unique
# Out:
# <bound method Series.unique of 20      Duracell USB Lightning Apple Certified (Mfi) B...
# 28      Duracell USB C To Lightning Apple Certified (M...
# 32      Zoul USB C 60W Fast Charging 3A 6ft/2M Long Ty...
# 33      Samsung Original Type C to C Cable - 3.28 Feet...
# 37      Sounce 65W OnePlus Dash Warp Charge Cable, 6.5...
#                               ...
# 1453                 Usha Hc 812 T Thermo Fan Room Heater
# 1456    4 in 1 Handheld Electric Vegetable Cutter Set,...
# 1458    Libra Room Heater for Home, Room Heaters Home ...
# 1459    NGI Store 2 Pieces Pet Hair Removers for Your ...
# 1462    Bajaj Majesty RX10 2000 Watts Heat Convector R...
# Name: product_name, Length: 325, dtype: object>

# %%
df[['product_name', 'rating_count']].isnull().sum()
# Out:
# product_name    0
# rating_count    0
# dtype: int64

# %%
from collections import Counter
import re

# %%
def extract_keywords(product_names):
    keywords = []
    for name in product_names:
        words = re.findall(r'\b\w+\b', name.lower())
        keywords.extend(words)
    return keywords

# %%
keywords = extract_keywords(df['product_name'])

# %%
keyword_counts = Counter(keywords)

# %%
keyword_counts_df = pd.DataFrame(keyword_counts.items(), columns=['keyword', 'count'])

# %%
keyword_counts_df = keyword_counts_df.sort_values(by='count', ascending=False)
keyword_counts_df
# Out:
#      keyword  count
# 10       for    204
# 66      with    153
# 9      cable    116
# 20         1    101
# 22     black     96
# ...      ...    ...
# 1815     ngi      1
# 1810      as      1
# 1809    meat      1
# 1808  celery      1
# 1825    rx10      1
#
# [1826 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='count', y='keyword', data=keyword_counts_df.head(10), palette='viridis')
plt.title('Top 10 Most Popular Product Keywords')
plt.xlabel('Count')
plt.ylabel('Keyword')
plt.show()

# %%
# The most Popular Product Keyword is For

# %% [markdown]
# ### Ques - 7.What are the most popular product reviews?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df['full_review'] = df['review_title'] + ' ' + df['review_content']

# %%
review_counts = df['full_review'].value_counts()

# %%
review_counts_df = review_counts.reset_index()
review_counts_df.columns = ['review', 'count']

# %%
review_counts_df = review_counts_df.sort_values(by='count', ascending=False)
review_counts_df.head(10)
# Out:
#                                               review  count
# 0  Good product,Its good, but micro usb doesn't f...      3
# 3  Great Cable, Charging Speeds Could Be Better,G...      3
# 4  Very good product.,Using as a spare cable in c...      3
# 2  Get it with bundled discounts.,Heating & Touch...      3
# 1  Good cable for car,Good substitute for orginal...      3
# 5  Product is as expected,Cable has problem with ...      2
# 6  Used for 10 months,Quality is good,Good Afters...      2
# 7  Good product,Strong and powerful,Useful produc...      2
# 8  Nice,Awesome,Quick not charger🤏,Expensive at t...      2
# 9  Iphone User,Overall good,Perfect price, perfec...      2

# %% [markdown]
# ### Ques-What is the correlation between discounted_price and rating?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'full_review'],
#       dtype='object')

# %%
df[['discounted_price', 'rating']].isnull().sum()
# Out:
# discounted_price    114
# rating                0
# dtype: int64

# %%
df = df.dropna(subset=['discounted_price', 'rating'])

# %%
df[['discounted_price', 'rating']].isnull().sum()
# Out:
# discounted_price    0
# rating              0
# dtype: int64

# %%
correlation = df['discounted_price'].corr(df['rating'])
correlation
# Out:
# np.float64(0.019710413265598265)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='discounted_price', y='rating', data=df, alpha=0.6)
plt.title('Scatter Plot of Discounted Price vs. Rating')
plt.xlabel('Discounted Price')
plt.ylabel('Rating')
plt.legend()
plt.show()

# %% [markdown]
# ### Ques- 9. What are the Top 5 categories based on the highest ratings.

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link', 'full_review'],
#       dtype='object')

# %%
average_ratings = df.groupby('category')['rating'].mean().reset_index()

# %%
average_ratings = average_ratings.sort_values(by='rating', ascending=False)

# %%
average_ratings.head(5)
# Out:
#                                              category  rating
# 4   Computers&Accessories|Accessories&Peripherals|...    5.00
# 22  Electronics|Mobiles&Accessories|MobileAccessor...    4.40
# 23  Electronics|Mobiles&Accessories|MobileAccessor...    4.40
# 14  Electronics|GeneralPurposeBatteries&BatteryCha...    4.35
# 13  Electronics|GeneralPurposeBatteries&BatteryCha...    4.35

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='rating', y='category', data=average_ratings.head(5) ,palette='viridis')
plt.title('Top 5 Categories Based on Highest Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# ### Ques- 10. Identify any potential areas for improvement or optimization based on the data analysis ?

# %% [markdown]
# #### 1. Product Pricing Strategy
# ##### Analysis:
# Examine the correlation between discounted_price and rating. If higher prices correlate with lower ratings, consider adjusting pricing strategies.
# ##### Action:
# Implement competitive pricing or promotional discounts for products with lower ratings to boost sales.
#
# #### 2. Product Categories
# ##### Analysis:
# Identify categories with low average ratings or high return rates. Compare these with categories that have high ratings.
# ##### Action:
# Focus on improving product quality or customer service in underperforming categories. Consider phasing out poorly rated products.
# #### 3. Customer Reviews and Feedback
# ##### Analysis:
# Analyze the content of reviews to identify common complaints or suggestions. Use sentiment analysis to gauge overall customer sentiment.
# ##### Action:
# Address recurring issues in product design, functionality, or customer service. Respond to customer feedback to improve satisfaction.
# #### 4. Inventory Management
# ##### Analysis:
# Examine sales trends over time to identify seasonal patterns or products with fluctuating demand.
# ##### Action:
# Optimize inventory levels to reduce stockouts or overstock situations. Implement just-in-time inventory practices for high-demand products.
# #### 5. Marketing and Promotion
# ##### Analysis:
# Evaluate the effectiveness of marketing campaigns by analyzing sales data before and after promotions.
# ##### Action:
# Adjust marketing strategies based on what works best. Consider targeted promotions for high-rated products to increase visibility.
# #### 6. Product Descriptions and Keywords
# ##### Analysis:
# Review product names and descriptions for SEO optimization. Identify popular keywords from high-rated products.
# ##### Action:
# Optimize product listings with relevant keywords to improve search visibility and attract more customers.
# #### 7. Customer Segmentation
# ##### Analysis:
# Segment customers based on purchasing behavior, demographics, or feedback. Identify which segments are most satisfied or dissatisfied.
# ##### Action:
# Tailor marketing strategies and product offerings to different customer segments to enhance engagement and satisfaction.
# #### 8. Return Rates and Customer Satisfaction
# ##### Analysis:
# If available, analyze return rates in relation to product ratings and customer reviews.
# ##### Action:
# Investigate the reasons for returns and address any quality issues. Improve product descriptions to set accurate expectations.
# #### 9. Competitor Analysis
# ##### Analysis:
# Compare your products' ratings and prices with competitors in the same category.
# ##### Action:
# Identify gaps in your offerings and adjust your product line or pricing strategy accordingly.
# #### 10. User Experience on the Platform
# ##### Analysis:
# If you have access to user interaction data, analyze how customers navigate your product listings.
# ##### Action:
# Improve the user interface and experience based on user behavior to enhance conversion rates.

# %% [markdown]
# # EDA - 4
#
# ## Title Of DataSet :- Spotify Data: Popular Hip-hop Artists and Tracks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('spotify.csv')

# %%
df.shape
# Out:
# (440, 5)

# %%
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %%
df.tail()
# Out:
#              Artist                                         Track Name  \
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 435          44         221863  3fBsEOnzwtlkpS0LxXAZhN
# 436          64         191900  7Ezwtgfw7khBrpvaNPtMoT
# 437          69         283693  7xVLFuuYdAvcTfcP3IG3dS
# 438          65         220408  4hGmQboiou09EwhcTWa0H6
# 439          68         267720  0nq6sfr8z1R5KJ4XUk396e

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
df.describe()
# Out:
#        Popularity  Duration (ms)
# count  440.000000     440.000000
# mean    75.736364  206810.040909
# std      9.886534   53576.930289
# min     29.000000   81666.000000
# 25%     70.000000  172778.500000
# 50%     77.000000  201866.000000
# 75%     83.000000  235119.750000
# max     97.000000  501648.000000

# %% [markdown]
# ### Ques-1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needfull.

# %%
# Read the dataframe
df = pd.read_csv('spotify.csv')

# %%
# Check for null values
df.isnull().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df = df.dropna() # there is no null value so no need to do this

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(27)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Ques-2.  What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Popularity'], bins=30, kde=True, color='blue')
plt.title('Distribution of Popularity Among Tracks')
plt.xlabel('Popularity Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Ques-3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 433  French Montana                                       Stand United
# 434    Jason Derulo                     Tip Toe (feat. French Montana)
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Duration (ms)', y='Popularity', color='blue')
plt.title('Relationship Between Popularity and Duration of Tracks')
plt.xlabel('Duration')
plt.ylabel('Popularity Score')
plt.show()

# %%
df['duration'] = df['Duration (ms)'] // 60000

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='duration', y='Popularity', color='blue')
plt.title('Relationship Between Popularity and Duration of Tracks')
plt.xlabel('Duration in minutes')
plt.ylabel('Popularity Score')
plt.show()

# %% [markdown]
# ### Ques- 4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID',
#        'Duration(m)', 'duration'],
#       dtype='object')

# %%
df.Artist.unique()
# Out:
# array(['Drake', 'Travis Scott', 'Post Malone', 'Noah Kahan',
#        'Nicki Minaj', 'Justin Bieber', 'Jessie J', 'KAROL G', '21 Savage',
#        'Metro Boomin', 'SZA', 'Jack Harlow', 'Jung Kook', 'Lil Nas X',
#        'Lyrical Lemonade', 'Future', 'Don Toliver', 'Lil Wayne', 'Yeat',
#        'Eminem', 'Kendrick Lamar', 'Baby Keem', 'The Weeknd', 'JAY-Z',
#        'Cardi B', 'Bruno Mars', 'Ed Sheeran', 'GloRilla', 'Gunna',
#        'Lil Baby', 'Internet Money', 'Sarz', 'J. Cole', 'Lil Durk',
#        'cassö', 'D-Block Europe', 'Clavish', 'Latto', 'Young Nudy',
#        'Megan Thee Stallion', 'NEIKED', 'Snoop Dogg', 'Dr. Dre',
#        'benny blanco', 'Young Thug', 'Chris Brown', 'Dave', 'Central Cee',
#        'The Kid LAROI', 'Quevedo', 'Bizarrap', 'Anuel AA', 'SAIKO',
#        'David Guetta', 'Coi Leray', 'Pressa', 'Fivio Foreign', 'RAYE',
#        'French Montana', 'Arizona Zervas', 'Pharrell Williams',
#        'XXXTENTACION', 'Kane Brown', 'Ellie Goulding', 'Reneé Rapp',
# ...

# %%
artist_track_count = df.Artist.value_counts().reset_index()
artist_track_count.columns = ['artist', 'track_count']
artist_track_count
# Out:
#           artist  track_count
# 0          Drake           17
# 1         Eminem           11
# 2      Lil Nas X           10
# 3          JAY-Z           10
# 4      21 Savage           10
# ..           ...          ...
# 110     Lil Tjay            1
# 111  BigXthaPlug            1
# 112      Fat Joe            1
# 113    A$AP Ferg            1
# 114        Diddy            1
#
# [115 rows x 2 columns]

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=artist_track_count.head(20), x='track_count', y='artist', palette='rainbow')
plt.title('Top 20 Artists by Number of Tracks')
plt.xlabel('Number of Tracks')
plt.ylabel('Artist')
plt.show()

# %%
# Drake has the highest number of tracks in the dataset

# %% [markdown]
# ### Ques-5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.

# %%
least_popular_tracks = df.sort_values(by='Popularity')

# %%
least_popular_tracks.head()
# Out:
#              Artist                     Track Name  Popularity  Duration (ms)  \
# 207          Pressa  Attachments (feat. Coi Leray)          29         171000
# 231   Justin Bieber                     Intentions          35         212853
# 413  French Montana                Splash Brothers          44         221863
# 225        Lil Baby                  On Me - Remix          47         135444
# 407     Wyclef Jean      911 (feat. Mary J. Blige)          48         259333
#
#                    Track ID  Duration(m)  duration
# 207  6EfJ8Ct3GHbBz2YlyPnMYb            2         2
# 231  7jAVt70Xdg8EwOtsFB1ZqK            3         3
# 413  3fBsEOnzwtlkpS0LxXAZhN            3         3
# 225  2uUFVnVFERNxUdcmvEs7LB            2         2
# 407  28hgx2bWXcaBJeC9zVwrBq            4         4

# %% [markdown]
# ### Ques - 6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist.

# %%
Most_popular_tracks = df.sort_values(by='Popularity', ascending=False)
Most_popular_tracks.head()
# Out:
#            Artist                               Track Name  Popularity  \
# 40    Jack Harlow                              Lovin On Me          97
# 260            ¥$                                 CARNIVAL          96
# 70      21 Savage                                   redrum          96
# 30   Travis Scott               FE!N (feat. Playboi Carti)          93
# 0           Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92
#
#      Duration (ms)                Track ID  Duration(m)  duration
# 40          138411  4xhsWYTOGcal8zt0J161CU            2         2
# 260         264324  3w0w2T288dec0mgeZZqoNN            4         4
# 70          270697  52eIcoLUM25zbQupAZYoFh            4         4
# 30          191700  42VsgItocQwOQC3XWZ8JNA            3         3
# 0           319191  1yeB8MUNeLo9Ek1UEpsyz6            5         5

# %%
avg_popularity_of_artist = df.groupby('Artist')['Popularity'].mean().reset_index()
avg_popularity_of_artist
# Out:
#                      Artist  Popularity
# 0                    *NSYNC       67.00
# 1                  2 Chainz       72.00
# 2                 21 Savage       83.80
# 3    A Boogie Wit da Hoodie       80.00
# 4                 A$AP Ferg       69.00
# ..                      ...         ...
# 110              Young Nudy       67.00
# 111              Young Thug       73.75
# 112            benny blanco       72.00
# 113                   cassö       92.00
# 114                      ¥$       85.10
#
# [115 rows x 2 columns]

# %%
avg_popularity_of_artist.sort_values(by='Popularity', ascending=False).head()
# Out:
#            Artist  Popularity
# 113         cassö   92.000000
# 104        Trueno   89.000000
# 24   David Guetta   87.000000
# 103  Travis Scott   86.555556
# 114            ¥$   85.100000

# %% [markdown]
# ### Ques - 7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist.

# %%
top_artists = avg_popularity_of_artist.sort_values(by='Popularity', ascending=False).head()
top_artists
# Out:
#            Artist  Popularity
# 113         cassö   92.000000
# 104        Trueno   89.000000
# 24   David Guetta   87.000000
# 103  Travis Scott   86.555556
# 114            ¥$   85.100000

# %%
most_popular_tracks = []
for artist in top_artists['Artist']:
    artist_tracks = df[df['Artist'] == artist]
    most_popular_track = artist_tracks.loc[artist_tracks['Popularity'].idxmax()]
    most_popular_tracks.append({
        'Artist': most_popular_track['Artist'],
        'Track Name': most_popular_track['Track Name'],
        'Popularity': most_popular_track['Popularity']
    })

# %%
pd.DataFrame(most_popular_tracks)
# Out:
#          Artist                    Track Name  Popularity
# 0         cassö                         Prada          92
# 1        Trueno  Mamichula - con Nicki Nicole          89
# 2  David Guetta            Baby Don't Hurt Me          87
# 3  Travis Scott    FE!N (feat. Playboi Carti)          93
# 4            ¥$                      CARNIVAL          96

# %% [markdown]
# ### Ques - 8.  Visualize relationships between multiple numerical variables simultaneously using a pair plot.

# %%
df.columns
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID',
#        'Duration(m)', 'duration'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 413 entries, 0 to 438
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         413 non-null    object
#  1   Track Name     413 non-null    object
#  2   Popularity     413 non-null    int64
#  3   Duration (ms)  413 non-null    int64
#  4   Track ID       413 non-null    object
#  5   Duration(m)    413 non-null    int64
#  6   duration       413 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 25.8+ KB

# %%
numeric_cols = ['Popularity', 'Duration (ms)']

# %%
sns.pairplot(df[numeric_cols])
plt.show()

# %% [markdown]
# ### Ques- 9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Artist', y='Duration (ms)', data=df, palette='viridis')
plt.xticks(rotation=90) 
plt.title('Box Plot of Track Duration by Artist')
plt.xlabel('Artist')
plt.ylabel('Duration (ms)')
plt.show()

# %% [markdown]
# ### Ques- 10. How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot.

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(x='Artist', y='Popularity', data=df)
plt.xticks(rotation=90)
plt.title('Swarm Plot of Track Popularity by Artist')
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Artist', y='Popularity', data=df, palette='rainbow')
plt.xticks(rotation=90) 
plt.title('Violin Plot of Track Popularity by Artist')
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.show()
